# %%
from endee import Endee, Precision

# %%
client = Endee()

# %%
client.create_index(
    name="my_index2",
    dimension=384,
    space_type="cosine",
    precision=Precision.INT8
)
# Out:
# 'Index created successfully'
